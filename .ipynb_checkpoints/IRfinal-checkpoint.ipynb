# %%
import logging
import re
import sys
from bs4 import BeautifulSoup
from queue import Queue
from urllib import parse, request
from urllib.parse import urlparse
import heapq
from urllib.robotparser import RobotFileParser
from selenium import webdriver

# %%
site = "https://ocw.mit.edu/search/?d=Electrical%20Engineering%20and%20Computer%20Science"
page = requests.get(site)
#print(page.text)
soup = BeautifulSoup(page.content, "html.parser")
# Out:
# 2024-04-30 11:58:53 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): ocw.mit.edu:443
# 2024-04-30 11:58:54 [urllib3.connectionpool] DEBUG: https://ocw.mit.edu:443 "GET /search/?d=Electrical%20Engineering%20and%20Computer%20Science HTTP/1.1" 200 2465

# %% [markdown]
# ##### OCW MIT
#
# Starting URL: https://ocw.mit.edu/search/?d=Electrical%20Engineering%20and%20Computer%20Science&q=computer%20science
#
# Courses Format:https://ocw.mit.edu/courses
#
# Course1: https://ocw.mit.edu/courses/6-001-structure-and-interpretation-of-computer-programs-spring-2005/
# Course2: https://ocw.mit.edu/courses/6-042j-mathematics-for-computer-science-fall-2010/
#
# Course Format: https://ocw.mit.edu/courses/[course # , title, date created]/
# - EECS courses seem to be 6.###A-Z
#
# Syllabus: https://ocw.mit.edu/courses/6-001-structure-and-interpretation-of-computer-programs-spring-2005/pages/syllabus/
#
# Format: courseurl + "pages/syllabus/"
#
# Example of graduate course: https://ocw.mit.edu/courses/mas-865j-quantum-information-science-spring-2006/
# - mas for masters?

# %% [markdown]
# Title
#
# Course Description
#
# Syllabus url

# %%
# main 
links = get_links(site)
writelines('links.txt', links)

print(links)

nonlocal_links = get_nonlocal_links(site)
writelines('nonlocal.txt', nonlocal_links)

visited, extracted = crawl(site)
#writelines('visited.txt', visited)
#writelines('extracted.txt', extracted)
#print(nonlocal_links)
print("visited", visited)
print("-------------------")
print(extracted)
# Out:
# 2024-04-30 11:58:58 [selenium.webdriver.common.selenium_manager] DEBUG: Selenium Manager binary found at: /Users/loiswong/anaconda3/lib/python3.11/site-packages/selenium/webdriver/common/macos/selenium-manager
# 2024-04-30 11:58:58 [selenium.webdriver.common.selenium_manager] DEBUG: Executing process: /Users/loiswong/anaconda3/lib/python3.11/site-packages/selenium/webdriver/common/macos/selenium-manager --browser chrome --language-binding python --output json
# 2024-04-30 11:59:00 [selenium.webdriver.common.selenium_manager] DEBUG: Driver path: /Users/loiswong/.cache/selenium/chromedriver/mac-x64/124.0.6367.91/chromedriver
# 2024-04-30 11:59:00 [selenium.webdriver.common.selenium_manager] DEBUG: Browser path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
# 2024-04-30 11:59:00 [selenium.webdriver.common.selenium_manager] DEBUG: Using driver at: /Users/loiswong/.cache/selenium/chromedriver/mac-x64/124.0.6367.91/chromedriver
# 2024-04-30 11:59:00 [selenium.webdriver.common.service] DEBUG: Started executable: `/Users/loiswong/.cache/selenium/chromedriver/mac-x64/124.0.6367.91/chromedriver` in a child process with pid: 28405 using 0 to output -3
# 2024-04-30 11:59:00 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://localhost:60352/session {'capabilities': {'firstMatch': [{}], 'alwaysMatch': {'browserName': 'chrome', 'pageLoadStrategy': <PageLoadStrategy.normal: 'normal'>, 'browserVersion': None, 'goog:chromeOptions': {'extensions': [], 'binary': '/Applications/Google Chrome.app/Contents/MacOS/Google Chrome', 'args': []}}}}
# 2024-04-30 11:59:00 [urllib3.connectionpool] DEBUG: Starting new HTTP connection (1): localhost:60352
# 2024-04-30 11:59:01 [urllib3.connectionpool] DEBUG: http://localhost:60352 "POST /session HTTP/1.1" 200 0
# 2024-04-30 11:59:01 [selenium.webdriver.remote.remote_connection] DEBUG: Remote response: status=200 | data={"value":{"capabilities":{"acceptInsecureCerts":false,"browserName":"chrome","browserVersion":"124.0.6367.91","chrome":{"chromedriverVersion":"124.0.6367.91 (51df0e5e17a8b0a4f281c1665dbd1b8a0c6b46af-refs/branch-heads/6367@{#984})","userDataDir":"/var/folders/9v/hmxqbznd0xn0yh8ks79srp100000gn/T/.org.chromium.Chromium.yJ1W1e"},"fedcm:accounts":true,"goog:chromeOptions":{"debuggerAddress":"localhost:60373"},"networkConnectionEnabled":false,"pageLoadStrategy":"normal","platformName":"mac","proxy":{},"setWindowRect":true,"strictFileInteractability":false,"timeouts":{"implicit":0,"pageLoad":300000,"script":30000},"unhandledPromptBehavior":"dismiss and notify","webauthn:extension:credBlob":true,"webauthn:extension:largeBlob":true,"webauthn:extension:minPinLength":true,"webauthn:extension:prf":true,"webauthn:virtualAuthenticators":true},"sessionId":"582fa6350530e4b11fdd6a1628305ff4"}} | headers=HTTPHeaderDict({'Content-Length': '889', 'Content-Type': 'application/json; charset=utf-8', 'cache-control': 'no-cache'})
# 2024-04-30 11:59:01 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2024-04-30 11:59:01 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://localhost:60352/session/582fa6350530e4b11fdd6a1628305ff4/url {'url': 'https://ocw.mit.edu/search/?d=Electrical%20Engineering%20and%20Computer%20Science'}
# 2024-04-30 11:59:02 [urllib3.connectionpool] DEBUG: http://localhost:60352 "POST /session/582fa6350530e4b11fdd6a1628305ff4/url HTTP/1.1" 200 0
# 2024-04-30 11:59:02 [selenium.webdriver.remote.remote_connection] DEBUG: Remote response: status=200 | data={"value":null} | headers=HTTPHeaderDict({'Content-Length': '14', 'Content-Type': 'application/json; charset=utf-8', 'cache-control': 'no-cache'})
# 2024-04-30 11:59:02 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2024-04-30 11:59:02 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://localhost:60352/session/582fa6350530e4b11fdd6a1628305ff4/timeouts {'implicit': 10000}
# 2024-04-30 11:59:02 [urllib3.connectionpool] DEBUG: http://localhost:60352 "POST /session/582fa6350530e4b11fdd6a1628305ff4/timeouts HTTP/1.1" 200 0
# 2024-04-30 11:59:02 [selenium.webdriver.remote.remote_connection] DEBUG: Remote response: status=200 | data={"value":null} | headers=HTTPHeaderDict({'Content-Length': '14', 'Content-Type': 'application/json; charset=utf-8', 'cache-control': 'no-cache'})
# 2024-04-30 11:59:02 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2024-04-30 11:59:02 [selenium.webdriver.remote.remote_connection] DEBUG: GET http://localhost:60352/session/582fa6350530e4b11fdd6a1628305ff4/source {}
# 2024-04-30 11:59:02 [urllib3.connectionpool] DEBUG: http://localhost:60352 "GET /session/582fa6350530e4b11fdd6a1628305ff4/source HTTP/1.1" 200 0
# 2024-04-30 11:59:02 [selenium.webdriver.remote.remote_connection] DEBUG: Remote response: status=200 | data={"value":"\u003Chtml lang=\"en\">\u003Chead>\n  \n    \n    \u003Cscript type=\"text/javascript\" async=\"\" src=\"https://script.crazyegg.com/pages/scripts/0017/3534.js\">\u003C/script>\u003Cscript type=\"text/javascript\" async=\"\" src=\"https://www.google-analytics.com/analytics.js\">\u003C/script>\u003Cscript type=\"text/javascript\" async=\"\" src=\"https://www.googletagmanager.com/gtag/js?id=G-NWDK3DX66P&amp;l=dataLayer&amp;cx=c\">\u003C/script>\u003Cscript async=\"\" src=\"https://www.googletagmanager.com/gtm.js?id=GTM-NMQZ25T\">\u003C/script>\u003Cscript>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':\n    new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],\n    j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=\n    'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);\n    })(window,document,'script','dataLayer','GTM-NMQZ25T');\u003C/script>\n    \n  \n  \n\n\n\n\n    \n    \u003Clink href=\"/static_shared/css/www.9c9b8.css\" rel=\"stylesheet\">\n    \n\n    \n    \u003Clink href=\"/static_shared/css/common.9c9b8.css\" rel=\"stylesheet\">\n    \n\n\u003Clink href=\"//cdn-images.mailchimp.com/embedcode/classic-10_7.css\" rel=\"stylesheet\" type=\"text/css\">\n\n  \n  \u003Cmeta charset=\"utf-8\">\n  \u003Cmeta name=\"viewport\" content=\"width=device-width, initial-scale=1, viewport-fit=cover\">\n  \n\n  \u003Cmeta name=\"description\" content=\"MIT OpenCourseWare is a web based publication of virtually all MIT course content. OCW is open and available to the world and is a permanent MIT activity\">\n  \u003Cmeta name=\"keywords\" content=\"opencourseware,MIT OCW,courseware,MIT opencourseware,Free Courses,class notes,class syllabus,class materials,tutorials,online courses,MIT courses\">\n  \n  \u003Cmeta property=\"og:site_name\" content=\"MIT OpenCourseWare\">\n  \u003Cmeta property=\"og:type\" content=\"website\">\n  \u003Cmeta property=\"og:url\" content=\"https://ocw.mit.edu/search/\">\n  \u003Cmeta property=\"og:title\" content=\"Search | MIT OpenCourseWare | Free Online Course Materials\">\n  \u003Cmeta property=\"og:description\" content=\"MIT OpenCourseWare is a web based publication of virtually all MIT course content. OCW is open and available to the world and is a permanent MIT activity\">\n\n  \u003Cmeta property=\"og:image\" content=\"https://ocw.mit.edu/static_shared/images/ocw_logo_orange.202255b67af1a72a1f52.png\">\n\n  \n  \u003Clink rel=\"canonical\" href=\"https://ocw.mit.edu/search/\">\n\n  \u003Cscript type=\"application/ld+json\">\n      {\n        \"@context\": \"http://schema.org/\",\n        \"@type\" : \"WebPage\",\n        \"name\": \"MIT OpenCourseWare\",\n        \"description\": \"MIT OpenCourseWare is a web based publication of virtually all MIT course content. OCW is open and available to the world and is a permanent MIT activity\",\n        \"license\": \"http://creativecommons.org/licenses/by-nc-sa/4.0/\", \n        \"publisher\": {\n          \"@type\": \"CollegeOrUniversity\",\n          \"name\": \"MIT OpenCourseWare\"\n        }\n      }\n  \u003C/script>\n\n  \u003Ctitle>Search | MIT OpenCourseWare | Free Online Course Materials\u003C/title>\n  \u003Cstyle>\n  @font-face {\n    font-family: 'Material Icons';\n    font-style: normal;\n    font-weight: 400;\n    src: local('Material Icons'),\n      local('MaterialIcons-Regular'),\n      url(/static_shared/fonts/MaterialIcons-Regular.subset.b08783e1dce436d1fc48.woff2) format('woff2'),\n      url(/static_shared/fonts/MaterialIcons-Regular.subset.a7504957787832d02dc4.woff) format('woff'),\n      url(/static_shared/fonts/MaterialIcons-Regular.subset.5e2e1a2780011ba8ef6b.ttf) format('truetype');\n  }\n  @font-face {\n    font-family: 'Material Icons Round';\n    font-style: normal;\n    font-weight: 400;\n    src: local(\"MaterialIcons-Round\"),\n    ...
# 2024-04-30 11:59:02 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2024-04-30 11:59:03 [selenium.webdriver.remote.remote_connection] DEBUG: DELETE http://localhost:60352/session/582fa6350530e4b11fdd6a1628305ff4 {}
# 2024-04-30 11:59:03 [urllib3.connectionpool] DEBUG: http://localhost:60352 "DELETE /session/582fa6350530e4b11fdd6a1628305ff4 HTTP/1.1" 200 0
# 2024-04-30 11:59:03 [selenium.webdriver.remote.remote_connection] DEBUG: Remote response: status=200 | data={"value":null} | headers=HTTPHeaderDict({'Content-Length': '14', 'Content-Type': 'application/json; charset=utf-8', 'cache-control': 'no-cache'})
# 2024-04-30 11:59:03 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2024-04-30 11:59:03 [selenium.webdriver.common.selenium_manager] DEBUG: Selenium Manager binary found at: /Users/loiswong/anaconda3/lib/python3.11/site-packages/selenium/webdriver/common/macos/selenium-manager
# 2024-04-30 11:59:03 [selenium.webdriver.common.selenium_manager] DEBUG: Executing process: /Users/loiswong/anaconda3/lib/python3.11/site-packages/selenium/webdriver/common/macos/selenium-manager --browser chrome --language-binding python --output json
# [<div class="lr-row course-title"><a class="w-100" href="/courses/6-092-introduction-to-programming-in-java-january-iap-2010/"><div><span id="search-result-0-title">Introduction to Programming in Java</span></div></a></div>, <div class="lr-row course-title"><a class="w-100" href="/courses/2-830j-control-of-manufacturing-processes-sma-6303-spring-2008/"><div><span id="search-result-1-title">Control of Manufacturing Processes (SMA 6303)</span></div></a></div>, <div class="lr-row course-title"><a class="w-100" href="/courses/6-007-electromagnetic-energy-from-motors-to-lasers-spring-2011/"><div><span id="search-result-2-title">Electromagnetic Energy: From Motors to Lasers</span></div></a></div>, <div class="lr-row course-title"><a class="w-100" href="/courses/6-974-fundamentals-of-photonics-quantum-electronics-spring-2006/"><div><span id="search-result-3-title">Fundamentals of Photonics: Quantum Electronics</span></div></a></div>, <div class="lr-row course-title"><a class="w-100" href="/courses/6-453-quantum-optical-communication-fall-2016/"><div><span id="search-result-4-title">Quantum Optical Communication</span></div></a></div>, <div class="lr-row course-title"><a class="w-100" href="/courses/6-630-electromagnetics-fall-2006/"><div><span id="search-result-5-title">Electromagnetics</span></div></a></div>, <div class="lr-row course-title"><a class="w-100" href="/courses/6-763-applied-superconductivity-fall-2005/"><div><span id="search-result-6-title">Applied Superconductivity</span></div></a></div>, <div class="lr-row course-title"><a class="w-100" href="/courses/6-823-computer-system-architecture-fall-2005/"><div><span id="search-result-7-title">Computer System Architecture</span></div></a></div>, <div class="lr-row course-title"><a class="w-100" href="/courses/6-012-microelectronic-devices-and-circuits-fall-2009/"><div><span id="search-result-8-title">Microelectronic Devices and Circuits</span></div></a></div>, <div class="lr-row course-title"><a class="w-100" href="/courses/6-189-a-gentle-introduction-to-programming-using-python-january-iap-2011/"><div><span id="search-result-9-title">A Gentle Introduction to Programming Using Python</span></div></a></div>]
# ['https://ocw.mit.edu/courses/6-092-introduction-to-programming-in-java-january-iap-2010/', 'https://ocw.mit.edu/courses/2-830j-control-of-manufacturing-processes-sma-6303-spring-2008/', 'https://ocw.mit.edu/courses/6-007-electromagnetic-energy-from-motors-to-lasers-spring-2011/', 'https://ocw.mit.edu/courses/6-974-fundamentals-of-photonics-quantum-electronics-spring-2006/', 'https://ocw.mit.edu/courses/6-453-quantum-optical-communication-fall-2016/', 'https://ocw.mit.edu/courses/6-630-electromagnetics-fall-2006/', 'https://ocw.mit.edu/courses/6-763-applied-superconductivity-fall-2005/', 'https://ocw.mit.edu/courses/6-823-computer-system-architecture-fall-2005/', 'https://ocw.mit.edu/courses/6-012-microelectronic-devices-and-circuits-fall-2009/', 'https://ocw.mit.edu/courses/6-189-a-gentle-introduction-to-programming-using-python-january-iap-2011/']
# 2024-04-30 11:59:03 [selenium.webdriver.common.selenium_manager] DEBUG: Driver path: /Users/loiswong/.cache/selenium/chromedriver/mac-x64/124.0.6367.91/chromedriver
# 2024-04-30 11:59:03 [selenium.webdriver.common.selenium_manager] DEBUG: Browser path: /Applications/Google Chrome.app/Contents/MacOS/Google Chrome
# 2024-04-30 11:59:03 [selenium.webdriver.common.selenium_manager] DEBUG: Using driver at: /Users/loiswong/.cache/selenium/chromedriver/mac-x64/124.0.6367.91/chromedriver
# 2024-04-30 11:59:03 [selenium.webdriver.common.service] DEBUG: Started executable: `/Users/loiswong/.cache/selenium/chromedriver/mac-x64/124.0.6367.91/chromedriver` in a child process with pid: 28451 using 0 to output -3
# 2024-04-30 11:59:03 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://localhost:60420/session {'capabilities': {'firstMatch': [{}], 'alwaysMatch': {'browserName': 'chrome', 'pageLoadStrategy': <PageLoadStrategy.normal: 'normal'>, 'browserVersion': None, 'goog:chromeOptions': {'extensions': [], 'binary': '/Applications/Google Chrome.app/Contents/MacOS/Google Chrome', 'args': []}}}}
# 2024-04-30 11:59:03 [urllib3.connectionpool] DEBUG: Starting new HTTP connection (1): localhost:60420
# 2024-04-30 11:59:04 [urllib3.connectionpool] DEBUG: http://localhost:60420 "POST /session HTTP/1.1" 200 0
# 2024-04-30 11:59:04 [selenium.webdriver.remote.remote_connection] DEBUG: Remote response: status=200 | data={"value":{"capabilities":{"acceptInsecureCerts":false,"browserName":"chrome","browserVersion":"124.0.6367.91","chrome":{"chromedriverVersion":"124.0.6367.91 (51df0e5e17a8b0a4f281c1665dbd1b8a0c6b46af-refs/branch-heads/6367@{#984})","userDataDir":"/var/folders/9v/hmxqbznd0xn0yh8ks79srp100000gn/T/.org.chromium.Chromium.XQXaWv"},"fedcm:accounts":true,"goog:chromeOptions":{"debuggerAddress":"localhost:60427"},"networkConnectionEnabled":false,"pageLoadStrategy":"normal","platformName":"mac","proxy":{},"setWindowRect":true,"strictFileInteractability":false,"timeouts":{"implicit":0,"pageLoad":300000,"script":30000},"unhandledPromptBehavior":"dismiss and notify","webauthn:extension:credBlob":true,"webauthn:extension:largeBlob":true,"webauthn:extension:minPinLength":true,"webauthn:extension:prf":true,"webauthn:virtualAuthenticators":true},"sessionId":"8d125d3c65bb94693b1a021bb93653c2"}} | headers=HTTPHeaderDict({'Content-Length': '889', 'Content-Type': 'application/json; charset=utf-8', 'cache-control': 'no-cache'})
# 2024-04-30 11:59:04 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2024-04-30 11:59:04 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://localhost:60420/session/8d125d3c65bb94693b1a021bb93653c2/url {'url': 'https://ocw.mit.edu/search/?d=Electrical%20Engineering%20and%20Computer%20Science'}
# 2024-04-30 11:59:05 [urllib3.connectionpool] DEBUG: http://localhost:60420 "POST /session/8d125d3c65bb94693b1a021bb93653c2/url HTTP/1.1" 200 0
# 2024-04-30 11:59:05 [selenium.webdriver.remote.remote_connection] DEBUG: Remote response: status=200 | data={"value":null} | headers=HTTPHeaderDict({'Content-Length': '14', 'Content-Type': 'application/json; charset=utf-8', 'cache-control': 'no-cache'})
# 2024-04-30 11:59:05 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2024-04-30 11:59:05 [selenium.webdriver.remote.remote_connection] DEBUG: POST http://localhost:60420/session/8d125d3c65bb94693b1a021bb93653c2/timeouts {'implicit': 10000}
# 2024-04-30 11:59:05 [urllib3.connectionpool] DEBUG: http://localhost:60420 "POST /session/8d125d3c65bb94693b1a021bb93653c2/timeouts HTTP/1.1" 200 0
# 2024-04-30 11:59:05 [selenium.webdriver.remote.remote_connection] DEBUG: Remote response: status=200 | data={"value":null} | headers=HTTPHeaderDict({'Content-Length': '14', 'Content-Type': 'application/json; charset=utf-8', 'cache-control': 'no-cache'})
# 2024-04-30 11:59:05 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2024-04-30 11:59:05 [selenium.webdriver.remote.remote_connection] DEBUG: GET http://localhost:60420/session/8d125d3c65bb94693b1a021bb93653c2/source {}
# 2024-04-30 11:59:05 [urllib3.connectionpool] DEBUG: http://localhost:60420 "GET /session/8d125d3c65bb94693b1a021bb93653c2/source HTTP/1.1" 200 0
# 2024-04-30 11:59:05 [selenium.webdriver.remote.remote_connection] DEBUG: Remote response: status=200 | data={"value":"\u003Chtml lang=\"en\">\u003Chead>\n  \n    \n    \u003Cscript type=\"text/javascript\" async=\"\" src=\"https://script.crazyegg.com/pages/scripts/0017/3534.js\">\u003C/script>\u003Cscript type=\"text/javascript\" async=\"\" src=\"https://www.google-analytics.com/analytics.js\">\u003C/script>\u003Cscript type=\"text/javascript\" async=\"\" src=\"https://www.googletagmanager.com/gtag/js?id=G-NWDK3DX66P&amp;l=dataLayer&amp;cx=c\">\u003C/script>\u003Cscript async=\"\" src=\"https://www.googletagmanager.com/gtm.js?id=GTM-NMQZ25T\">\u003C/script>\u003Cscript>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':\n    new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],\n    j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=\n    'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);\n    })(window,document,'script','dataLayer','GTM-NMQZ25T');\u003C/script>\n    \n  \n  \n\n\n\n\n    \n    \u003Clink href=\"/static_shared/css/www.9c9b8.css\" rel=\"stylesheet\">\n    \n\n    \n    \u003Clink href=\"/static_shared/css/common.9c9b8.css\" rel=\"stylesheet\">\n    \n\n\u003Clink href=\"//cdn-images.mailchimp.com/embedcode/classic-10_7.css\" rel=\"stylesheet\" type=\"text/css\">\n\n  \n  \u003Cmeta charset=\"utf-8\">\n  \u003Cmeta name=\"viewport\" content=\"width=device-width, initial-scale=1, viewport-fit=cover\">\n  \n\n  \u003Cmeta name=\"description\" content=\"MIT OpenCourseWare is a web based publication of virtually all MIT course content. OCW is open and available to the world and is a permanent MIT activity\">\n  \u003Cmeta name=\"keywords\" content=\"opencourseware,MIT OCW,courseware,MIT opencourseware,Free Courses,class notes,class syllabus,class materials,tutorials,online courses,MIT courses\">\n  \n  \u003Cmeta property=\"og:site_name\" content=\"MIT OpenCourseWare\">\n  \u003Cmeta property=\"og:type\" content=\"website\">\n  \u003Cmeta property=\"og:url\" content=\"https://ocw.mit.edu/search/\">\n  \u003Cmeta property=\"og:title\" content=\"Search | MIT OpenCourseWare | Free Online Course Materials\">\n  \u003Cmeta property=\"og:description\" content=\"MIT OpenCourseWare is a web based publication of virtually all MIT course content. OCW is open and available to the world and is a permanent MIT activity\">\n\n  \u003Cmeta property=\"og:image\" content=\"https://ocw.mit.edu/static_shared/images/ocw_logo_orange.202255b67af1a72a1f52.png\">\n\n  \n  \u003Clink rel=\"canonical\" href=\"https://ocw.mit.edu/search/\">\n\n  \u003Cscript type=\"application/ld+json\">\n      {\n        \"@context\": \"http://schema.org/\",\n        \"@type\" : \"WebPage\",\n        \"name\": \"MIT OpenCourseWare\",\n        \"description\": \"MIT OpenCourseWare is a web based publication of virtually all MIT course content. OCW is open and available to the world and is a permanent MIT activity\",\n        \"license\": \"http://creativecommons.org/licenses/by-nc-sa/4.0/\", \n        \"publisher\": {\n          \"@type\": \"CollegeOrUniversity\",\n          \"name\": \"MIT OpenCourseWare\"\n        }\n      }\n  \u003C/script>\n\n  \u003Ctitle>Search | MIT OpenCourseWare | Free Online Course Materials\u003C/title>\n  \u003Cstyle>\n  @font-face {\n    font-family: 'Material Icons';\n    font-style: normal;\n    font-weight: 400;\n    src: local('Material Icons'),\n      local('MaterialIcons-Regular'),\n      url(/static_shared/fonts/MaterialIcons-Regular.subset.b08783e1dce436d1fc48.woff2) format('woff2'),\n      url(/static_shared/fonts/MaterialIcons-Regular.subset.a7504957787832d02dc4.woff) format('woff'),\n      url(/static_shared/fonts/MaterialIcons-Regular.subset.5e2e1a2780011ba8ef6b.ttf) format('truetype');\n  }\n  @font-face {\n    font-family: 'Material Icons Round';\n    font-style: normal;\n    font-weight: 400;\n    src: local(\"MaterialIcons-Round\"),\n    ...
# 2024-04-30 11:59:05 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# 2024-04-30 11:59:05 [selenium.webdriver.remote.remote_connection] DEBUG: DELETE http://localhost:60420/session/8d125d3c65bb94693b1a021bb93653c2 {}
# 2024-04-30 11:59:05 [urllib3.connectionpool] DEBUG: http://localhost:60420 "DELETE /session/8d125d3c65bb94693b1a021bb93653c2 HTTP/1.1" 200 0
# 2024-04-30 11:59:05 [selenium.webdriver.remote.remote_connection] DEBUG: Remote response: status=200 | data={"value":null} | headers=HTTPHeaderDict({'Content-Length': '14', 'Content-Type': 'application/json; charset=utf-8', 'cache-control': 'no-cache'})
# 2024-04-30 11:59:05 [selenium.webdriver.remote.remote_connection] DEBUG: Finished Request
# []
# name 'visitlog' is not defined https://ocw.mit.edu/search/?d=Electrical%20Engineering%20and%20Computer%20Science
# visited ['https://ocw.mit.edu/search/?d=Electrical%20Engineering%20and%20Computer%20Science']
# -------------------
# []

# %%
def parse_links(root, html):
    soup = BeautifulSoup(html, 'html.parser')
    for link in soup.find_all('a'):
        href = link.get('href')
        if href:
            text = link.string
            if not text:
                text = ''
            text = re.sub('\s+', ' ', text).strip()
            yield (parse.urljoin(root, link.get('href')), text) #HERE

# %%
def is_self_referencing_link(url, link): #check if this is right
    end_of_link = url.rsplit('/', 1)[-1]
    return end_of_link in link

# %%
def get_nonlocal_links(url):
    '''Get a list of links on the page specificed by the url,
    but only keep non-local links and non self-references.
    Return a list of (link, title) pairs, just like get_links()'''

    # TODO: implement
    domain = ""
    links = get_links(url)
    filtered = []

    for link, title in links: 
        if urlparse(link).netloc != domain:
            if not is_self_referencing_link(url, link):
                filtered.append((link, title))
    return filtered

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from urllib.parse import urljoin

def get_links(url):
    driver = webdriver.Chrome()  # using Selenium
    driver.get(url)  # link to scrape

    res = driver.page_source
    driver.quit()  # selenium

    soup = BeautifulSoup(res, 'html.parser')
    links = []
    
    #, class_='lr-row course-title'

    # Find all divs with class "lr-row course-title" and then find the <a> tags within them
    for div in soup.find_all('div'):
        print("DIV", div)
        for a in div.find_all('a', href=True):
            print("A", a)
            href = a.get('href')
            if href:
                full_url = urljoin(url, href)
                links.append(full_url)

    return links



# Example usage
url = 'https://ocw.mit.edu/search/?d=Electrical%20Engineering%20and%20Computer%20Science'
links = get_links(url)
print(links)
# Out:
# DIV <div>
# <div class="search-wrapper">
# <div class="position-relative bg-black medium-and-below-only" id="mobile-header">
# <nav class="navbar navbar-expand-lg navbar-dark bg-black d-flex">
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
# <i class="material-icons display-4 text-white align-bottom">menu</i>
# </button>
# <div class="mx-auto">
# <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg" width="250"/>
# </a>
# </div>
# <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav mr-auto pl-2 pt-2">
# <li class="nav-item">
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">Give Now</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/about">About OCW</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">Help &amp; Faqs</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/contact">Contact Us</a>
# </li>
# </ul>
# </div>
# </nav>
# </div>
# <div id="desktop-header">
# <div class="contents">
# <div class="left">
# <div class="ocw-logo">
# <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg"/>
# </a>
# </div>
# </div>
# <div class="right">
# <a aria-label="Donate to MIT OpenCourseWare" class="give-button text-white text-decoration-none font-weight-bold small-link d-flex align-items-center" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">
# <span class="m-0 pr-2">GIVE NOW</span>
# <img alt="" class="heart-burgundy" src="/static_shared/images/heart_burgundy.e7c8635e8cc6538b89fa.svg"/>
# </a>
# <a class="text-white text-decoration-none font-weight-bold pl-5 pr-3 py-2" href="/about">about ocw</a>
# <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">help &amp; faqs</a>
# <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="/contact">contact us</a>
# </div>
# </div>
# </div>
# <div class="container-fluid">
# <main>
# <div class="container-fluid p-0">
# <div class="row m-0">
# <div class="w-100" id="search-page"><div class="search-page w-100"><div class="container px-lg-0"><div class="search-box py-sm-5 py-md-7 py-lg-5 row"><div class="col-lg-3"></div><div class="col-lg-6 search-box-inner d-flex flex-column align-items-center mb-2 mb-sm-5 mb-md-4 ml-lg-3"><h1>Explore OpenCourseWare</h1><div><span class="align-item-center search-box-description">Search for courses, materials &amp; teaching resources</span></div><div class="w-100 d-flex flex-column align-items-center search-input-wrapper mt-5"><div class="w-100"><form class="search-box d-flex flex-direction-row" role="search"><input aria-label="Search OpenCourseWare" class="w-100 pl-2" placeholder="Search OpenCourseWare" type="search" value=""/><button class="py-2 px-3" type="submit">Search</button></form></div></div></div><div class="col-lg-3"></div></div><div class="row search-filter-drawer mx-auto px-lg-6"><div class="col-12 col-lg-3 mt-3 mt-lg-0 facet-display-wrapper pt-3 pl-0"><div class="active-search-filters"><div class="filter-section-main-title">Filters<button class="clear-all-filters-button" type="button">Clear All</button></div><div class="active-search-filter"><div>Electrical Engineering and Computer Science</div><button aria-label="clear filter" class="remove-filter-button" type="button"><span aria-hidden="true" class="material-icons">close</span></button></div></div><div class="facets filterable-facet mb-3"><button aria-expanded="true" class="filter-section-button pl-3 py-2 pr-0" type="button">Departments<i aria-hidden="true" class="material-icons arrow_drop_down">arrow_drop_down</i></button><div class="input-wrapper"><input class="facet-filter" placeholder="Search Departments" type="text" value=""/><i aria-hidden="true" class="input-postfix-icon material-icons search-icon mt-1">search</i></div><div class="facet-list"><div class="facet-visible checked"><input checked="" id="department-name-electrical-engineering-and-computer-science" name="department_name" type="checkbox" value="Electrical Engineering and Computer Science"/><div class="facet-label-div"><label class="facet-key" for="department-name-electrical-engineering-and-computer-science"><div>Electrical Engineering and Co…</div></label><div class="facet-count">0</div></div></div></div></div><div class="col-12"><footer class="search-footer"><img alt="MIT Open Learning" src="/static_shared/images/mit_ol.svg" width="140px"/><div class="mt-4"><a class="text-muted" href="https://accessibility.mit.edu" rel="noreferrer" target="_blank">Accessibility</a></div><div class="mt-2"><a class="text-muted" href="https://creativecommons.org/licenses/by-nc-sa/4.0/" rel="noreferrer" target="_blank">Creative Commons License</a></div><div class="mt-2"><a class="text-muted" href="/pages/privacy-and-terms-of-use/">Terms and Conditions</a></div><div class="text-muted mt-4">© 2001–2024 Massachusetts Institute of Technology</div></footer></div></div><div class="search-results-area col-12 col-lg-9 pb-2 pt-2 pr-lg-0"><div class="search-toggle facet"><ul class="nav pl-2 pb-2 d-flex flex-direction-row mb-1"><li class="nav-item flex-grow-0"><button class="nav-link search-nav active" type="button">Courses</button></li><li class="nav-item flex-grow-0"><button class="nav-link search-nav" type="button">Resources</button></li><li aria-atomic="true" aria-live="polite" class="nav-item flex-grow-1 d-flex align-items-center justify-content-end results-total"></li><li class="sort-nav-item nav-item d-flex align-items-center justify-content-end">Sort by <select class="ml-2 sort-dropdown"><option value="">Relevance</option><option value="department_course_numbers.sort_coursenum">MIT course #</option><option value="-runs.best_start_date">Date</option></select></li><div class="layout-buttons layout-buttons-desktop"><button aria-label="show detailed results" class="layout-button-left" type="button"><img alt="" aria-hidden="true" src="/images/icons/list_ui_icon.png"/></button><button aria-label="show compact results" class="layout ...
# </div>
# </div>
# </main>
# </div>
# </div>
# </div>
# A <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg" width="250"/>
# </a>
# A <a class="nav-link" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">Give Now</a>
# A <a class="nav-link" href="/about">About OCW</a>
# A <a class="nav-link" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">Help &amp; Faqs</a>
# A <a class="nav-link" href="/contact">Contact Us</a>
# A <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg"/>
# </a>
# A <a aria-label="Donate to MIT OpenCourseWare" class="give-button text-white text-decoration-none font-weight-bold small-link d-flex align-items-center" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">
# <span class="m-0 pr-2">GIVE NOW</span>
# <img alt="" class="heart-burgundy" src="/static_shared/images/heart_burgundy.e7c8635e8cc6538b89fa.svg"/>
# </a>
# A <a class="text-white text-decoration-none font-weight-bold pl-5 pr-3 py-2" href="/about">about ocw</a>
# A <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">help &amp; faqs</a>
# A <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="/contact">contact us</a>
# A <a class="text-muted" href="https://accessibility.mit.edu" rel="noreferrer" target="_blank">Accessibility</a>
# A <a class="text-muted" href="https://creativecommons.org/licenses/by-nc-sa/4.0/" rel="noreferrer" target="_blank">Creative Commons License</a>
# A <a class="text-muted" href="/pages/privacy-and-terms-of-use/">Terms and Conditions</a>
# DIV <div class="search-wrapper">
# <div class="position-relative bg-black medium-and-below-only" id="mobile-header">
# <nav class="navbar navbar-expand-lg navbar-dark bg-black d-flex">
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
# <i class="material-icons display-4 text-white align-bottom">menu</i>
# </button>
# <div class="mx-auto">
# <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg" width="250"/>
# </a>
# </div>
# <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav mr-auto pl-2 pt-2">
# <li class="nav-item">
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">Give Now</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/about">About OCW</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">Help &amp; Faqs</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/contact">Contact Us</a>
# </li>
# </ul>
# </div>
# </nav>
# </div>
# <div id="desktop-header">
# <div class="contents">
# <div class="left">
# <div class="ocw-logo">
# <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg"/>
# </a>
# </div>
# </div>
# <div class="right">
# <a aria-label="Donate to MIT OpenCourseWare" class="give-button text-white text-decoration-none font-weight-bold small-link d-flex align-items-center" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">
# <span class="m-0 pr-2">GIVE NOW</span>
# <img alt="" class="heart-burgundy" src="/static_shared/images/heart_burgundy.e7c8635e8cc6538b89fa.svg"/>
# </a>
# <a class="text-white text-decoration-none font-weight-bold pl-5 pr-3 py-2" href="/about">about ocw</a>
# <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">help &amp; faqs</a>
# <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="/contact">contact us</a>
# </div>
# </div>
# </div>
# <div class="container-fluid">
# <main>
# <div class="container-fluid p-0">
# <div class="row m-0">
# <div class="w-100" id="search-page"><div class="search-page w-100"><div class="container px-lg-0"><div class="search-box py-sm-5 py-md-7 py-lg-5 row"><div class="col-lg-3"></div><div class="col-lg-6 search-box-inner d-flex flex-column align-items-center mb-2 mb-sm-5 mb-md-4 ml-lg-3"><h1>Explore OpenCourseWare</h1><div><span class="align-item-center search-box-description">Search for courses, materials &amp; teaching resources</span></div><div class="w-100 d-flex flex-column align-items-center search-input-wrapper mt-5"><div class="w-100"><form class="search-box d-flex flex-direction-row" role="search"><input aria-label="Search OpenCourseWare" class="w-100 pl-2" placeholder="Search OpenCourseWare" type="search" value=""/><button class="py-2 px-3" type="submit">Search</button></form></div></div></div><div class="col-lg-3"></div></div><div class="row search-filter-drawer mx-auto px-lg-6"><div class="col-12 col-lg-3 mt-3 mt-lg-0 facet-display-wrapper pt-3 pl-0"><div class="active-search-filters"><div class="filter-section-main-title">Filters<button class="clear-all-filters-button" type="button">Clear All</button></div><div class="active-search-filter"><div>Electrical Engineering and Computer Science</div><button aria-label="clear filter" class="remove-filter-button" type="button"><span aria-hidden="true" class="material-icons">close</span></button></div></div><div class="facets filterable-facet mb-3"><button aria-expanded="true" class="filter-section-button pl-3 py-2 pr-0" type="button">Departments<i aria-hidden="true" class="material-icons arrow_drop_down">arrow_drop_down</i></button><div class="input-wrapper"><input class="facet-filter" placeholder="Search Departments" type="text" value=""/><i aria-hidden="true" class="input-postfix-icon material-icons search-icon mt-1">search</i></div><div class="facet-list"><div class="facet-visible checked"><input checked="" id="department-name-electrical-engineering-and-computer-science" name="department_name" type="checkbox" value="Electrical Engineering and Computer Science"/><div class="facet-label-div"><label class="facet-key" for="department-name-electrical-engineering-and-computer-science"><div>Electrical Engineering and Co…</div></label><div class="facet-count">0</div></div></div></div></div><div class="col-12"><footer class="search-footer"><img alt="MIT Open Learning" src="/static_shared/images/mit_ol.svg" width="140px"/><div class="mt-4"><a class="text-muted" href="https://accessibility.mit.edu" rel="noreferrer" target="_blank">Accessibility</a></div><div class="mt-2"><a class="text-muted" href="https://creativecommons.org/licenses/by-nc-sa/4.0/" rel="noreferrer" target="_blank">Creative Commons License</a></div><div class="mt-2"><a class="text-muted" href="/pages/privacy-and-terms-of-use/">Terms and Conditions</a></div><div class="text-muted mt-4">© 2001–2024 Massachusetts Institute of Technology</div></footer></div></div><div class="search-results-area col-12 col-lg-9 pb-2 pt-2 pr-lg-0"><div class="search-toggle facet"><ul class="nav pl-2 pb-2 d-flex flex-direction-row mb-1"><li class="nav-item flex-grow-0"><button class="nav-link search-nav active" type="button">Courses</button></li><li class="nav-item flex-grow-0"><button class="nav-link search-nav" type="button">Resources</button></li><li aria-atomic="true" aria-live="polite" class="nav-item flex-grow-1 d-flex align-items-center justify-content-end results-total"></li><li class="sort-nav-item nav-item d-flex align-items-center justify-content-end">Sort by <select class="ml-2 sort-dropdown"><option value="">Relevance</option><option value="department_course_numbers.sort_coursenum">MIT course #</option><option value="-runs.best_start_date">Date</option></select></li><div class="layout-buttons layout-buttons-desktop"><button aria-label="show detailed results" class="layout-button-left" type="button"><img alt="" aria-hidden="true" src="/images/icons/list_ui_icon.png"/></button><button aria-label="show compact results" class="layout ...
# </div>
# </div>
# </main>
# </div>
# </div>
# A <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg" width="250"/>
# </a>
# A <a class="nav-link" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">Give Now</a>
# A <a class="nav-link" href="/about">About OCW</a>
# A <a class="nav-link" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">Help &amp; Faqs</a>
# A <a class="nav-link" href="/contact">Contact Us</a>
# A <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg"/>
# </a>
# A <a aria-label="Donate to MIT OpenCourseWare" class="give-button text-white text-decoration-none font-weight-bold small-link d-flex align-items-center" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">
# <span class="m-0 pr-2">GIVE NOW</span>
# <img alt="" class="heart-burgundy" src="/static_shared/images/heart_burgundy.e7c8635e8cc6538b89fa.svg"/>
# </a>
# A <a class="text-white text-decoration-none font-weight-bold pl-5 pr-3 py-2" href="/about">about ocw</a>
# A <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">help &amp; faqs</a>
# A <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="/contact">contact us</a>
# A <a class="text-muted" href="https://accessibility.mit.edu" rel="noreferrer" target="_blank">Accessibility</a>
# A <a class="text-muted" href="https://creativecommons.org/licenses/by-nc-sa/4.0/" rel="noreferrer" target="_blank">Creative Commons License</a>
# A <a class="text-muted" href="/pages/privacy-and-terms-of-use/">Terms and Conditions</a>
# DIV <div class="position-relative bg-black medium-and-below-only" id="mobile-header">
# <nav class="navbar navbar-expand-lg navbar-dark bg-black d-flex">
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
# <i class="material-icons display-4 text-white align-bottom">menu</i>
# </button>
# <div class="mx-auto">
# <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg" width="250"/>
# </a>
# </div>
# <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav mr-auto pl-2 pt-2">
# <li class="nav-item">
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">Give Now</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/about">About OCW</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">Help &amp; Faqs</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/contact">Contact Us</a>
# </li>
# </ul>
# </div>
# </nav>
# </div>
# A <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg" width="250"/>
# </a>
# A <a class="nav-link" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">Give Now</a>
# A <a class="nav-link" href="/about">About OCW</a>
# A <a class="nav-link" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">Help &amp; Faqs</a>
# A <a class="nav-link" href="/contact">Contact Us</a>
# DIV <div class="mx-auto">
# <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg" width="250"/>
# </a>
# </div>
# A <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg" width="250"/>
# </a>
# DIV <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav mr-auto pl-2 pt-2">
# <li class="nav-item">
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">Give Now</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/about">About OCW</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">Help &amp; Faqs</a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/contact">Contact Us</a>
# </li>
# </ul>
# </div>
# A <a class="nav-link" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">Give Now</a>
# A <a class="nav-link" href="/about">About OCW</a>
# A <a class="nav-link" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">Help &amp; Faqs</a>
# A <a class="nav-link" href="/contact">Contact Us</a>
# DIV <div id="desktop-header">
# <div class="contents">
# <div class="left">
# <div class="ocw-logo">
# <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg"/>
# </a>
# </div>
# </div>
# <div class="right">
# <a aria-label="Donate to MIT OpenCourseWare" class="give-button text-white text-decoration-none font-weight-bold small-link d-flex align-items-center" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">
# <span class="m-0 pr-2">GIVE NOW</span>
# <img alt="" class="heart-burgundy" src="/static_shared/images/heart_burgundy.e7c8635e8cc6538b89fa.svg"/>
# </a>
# <a class="text-white text-decoration-none font-weight-bold pl-5 pr-3 py-2" href="/about">about ocw</a>
# <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">help &amp; faqs</a>
# <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="/contact">contact us</a>
# </div>
# </div>
# </div>
# A <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg"/>
# </a>
# A <a aria-label="Donate to MIT OpenCourseWare" class="give-button text-white text-decoration-none font-weight-bold small-link d-flex align-items-center" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">
# <span class="m-0 pr-2">GIVE NOW</span>
# <img alt="" class="heart-burgundy" src="/static_shared/images/heart_burgundy.e7c8635e8cc6538b89fa.svg"/>
# </a>
# A <a class="text-white text-decoration-none font-weight-bold pl-5 pr-3 py-2" href="/about">about ocw</a>
# A <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">help &amp; faqs</a>
# A <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="/contact">contact us</a>
# DIV <div class="contents">
# <div class="left">
# <div class="ocw-logo">
# <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg"/>
# </a>
# </div>
# </div>
# <div class="right">
# <a aria-label="Donate to MIT OpenCourseWare" class="give-button text-white text-decoration-none font-weight-bold small-link d-flex align-items-center" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">
# <span class="m-0 pr-2">GIVE NOW</span>
# <img alt="" class="heart-burgundy" src="/static_shared/images/heart_burgundy.e7c8635e8cc6538b89fa.svg"/>
# </a>
# <a class="text-white text-decoration-none font-weight-bold pl-5 pr-3 py-2" href="/about">about ocw</a>
# <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">help &amp; faqs</a>
# <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="/contact">contact us</a>
# </div>
# </div>
# A <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg"/>
# </a>
# A <a aria-label="Donate to MIT OpenCourseWare" class="give-button text-white text-decoration-none font-weight-bold small-link d-flex align-items-center" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">
# <span class="m-0 pr-2">GIVE NOW</span>
# <img alt="" class="heart-burgundy" src="/static_shared/images/heart_burgundy.e7c8635e8cc6538b89fa.svg"/>
# </a>
# A <a class="text-white text-decoration-none font-weight-bold pl-5 pr-3 py-2" href="/about">about ocw</a>
# A <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">help &amp; faqs</a>
# A <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="/contact">contact us</a>
# DIV <div class="left">
# <div class="ocw-logo">
# <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg"/>
# </a>
# </div>
# </div>
# A <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg"/>
# </a>
# DIV <div class="ocw-logo">
# <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg"/>
# </a>
# </div>
# A <a href="/">
# <img alt="MIT OpenCourseWare" src="/static_shared/images/ocw_logo_white.cabdc9a745b03db3dad4.svg"/>
# </a>
# DIV <div class="right">
# <a aria-label="Donate to MIT OpenCourseWare" class="give-button text-white text-decoration-none font-weight-bold small-link d-flex align-items-center" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">
# <span class="m-0 pr-2">GIVE NOW</span>
# <img alt="" class="heart-burgundy" src="/static_shared/images/heart_burgundy.e7c8635e8cc6538b89fa.svg"/>
# </a>
# <a class="text-white text-decoration-none font-weight-bold pl-5 pr-3 py-2" href="/about">about ocw</a>
# <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">help &amp; faqs</a>
# <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="/contact">contact us</a>
# </div>
# A <a aria-label="Donate to MIT OpenCourseWare" class="give-button text-white text-decoration-none font-weight-bold small-link d-flex align-items-center" href="https://giving.mit.edu/give/to/ocw/?utm_source=ocw&amp;utm_medium=homepage_banner&amp;utm_campaign=nextgen_home">
# <span class="m-0 pr-2">GIVE NOW</span>
# <img alt="" class="heart-burgundy" src="/static_shared/images/heart_burgundy.e7c8635e8cc6538b89fa.svg"/>
# </a>
# A <a class="text-white text-decoration-none font-weight-bold pl-5 pr-3 py-2" href="/about">about ocw</a>
# A <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="https://mitocw.zendesk.com/hc/en-us" target="_blank">help &amp; faqs</a>
# A <a class="text-white text-decoration-none font-weight-bold px-3 py-2" href="/contact">contact us</a>
# DIV <div class="container-fluid">
# <main>
# <div class="container-fluid p-0">
# <div class="row m-0">
# <div class="w-100" id="search-page"><div class="search-page w-100"><div class="container px-lg-0"><div class="search-box py-sm-5 py-md-7 py-lg-5 row"><div class="col-lg-3"></div><div class="col-lg-6 search-box-inner d-flex flex-column align-items-center mb-2 mb-sm-5 mb-md-4 ml-lg-3"><h1>Explore OpenCourseWare</h1><div><span class="align-item-center search-box-description">Search for courses, materials &amp; teaching resources</span></div><div class="w-100 d-flex flex-column align-items-center search-input-wrapper mt-5"><div class="w-100"><form class="search-box d-flex flex-direction-row" role="search"><input aria-label="Search OpenCourseWare" class="w-100 pl-2" placeholder="Search OpenCourseWare" type="search" value=""/><button class="py-2 px-3" type="submit">Search</button></form></div></div></div><div class="col-lg-3"></div></div><div class="row search-filter-drawer mx-auto px-lg-6"><div class="col-12 col-lg-3 mt-3 mt-lg-0 facet-display-wrapper pt-3 pl-0"><div class="active-search-filters"><div class="filter-section-main-title">Filters<button class="clear-all-filters-button" type="button">Clear All</button></div><div class="active-search-filter"><div>Electrical Engineering and Computer Science</div><button aria-label="clear filter" class="remove-filter-button" type="button"><span aria-hidden="true" class="material-icons">close</span></button></div></div><div class="facets filterable-facet mb-3"><button aria-expanded="true" class="filter-section-button pl-3 py-2 pr-0" type="button">Departments<i aria-hidden="true" class="material-icons arrow_drop_down">arrow_drop_down</i></button><div class="input-wrapper"><input class="facet-filter" placeholder="Search Departments" type="text" value=""/><i aria-hidden="true" class="input-postfix-icon material-icons search-icon mt-1">search</i></div><div class="facet-list"><div class="facet-visible checked"><input checked="" id="department-name-electrical-engineering-and-computer-science" name="department_name" type="checkbox" value="Electrical Engineering and Computer Science"/><div class="facet-label-div"><label class="facet-key" for="department-name-electrical-engineering-and-computer-science"><div>Electrical Engineering and Co…</div></label><div class="facet-count">0</div></div></div></div></div><div class="col-12"><footer class="search-footer"><img alt="MIT Open Learning" src="/static_shared/images/mit_ol.svg" width="140px"/><div class="mt-4"><a class="text-muted" href="https://accessibility.mit.edu" rel="noreferrer" target="_blank">Accessibility</a></div><div class="mt-2"><a class="text-muted" href="https://creativecommons.org/licenses/by-nc-sa/4.0/" rel="noreferrer" target="_blank">Creative Commons License</a></div><div class="mt-2"><a class="text-muted" href="/pages/privacy-and-terms-of-use/">Terms and Conditions</a></div><div class="text-muted mt-4">© 2001–2024 Massachusetts Institute of Technology</div></footer></div></div><div class="search-results-area col-12 col-lg-9 pb-2 pt-2 pr-lg-0"><div class="search-toggle facet"><ul class="nav pl-2 pb-2 d-flex flex-direction-row mb-1"><li class="nav-item flex-grow-0"><button class="nav-link search-nav active" type="button">Courses</button></li><li class="nav-item flex-grow-0"><button class="nav-link search-nav" type="button">Resources</button></li><li aria-atomic="true" aria-live="polite" class="nav-item flex-grow-1 d-flex align-items-center justify-content-end results-total"></li><li class="sort-nav-item nav-item d-flex align-items-center justify-content-end">Sort by <select class="ml-2 sort-dropdown"><option value="">Relevance</option><option value="department_course_numbers.sort_coursenum">MIT course #</option><option value="-runs.best_start_date">Date</option></select></li><div class="layout-buttons layout-buttons-desktop"><button aria-label="show detailed results" class="layout-button-left" type="button"><img alt="" aria-hidden="true" src="/images/icons/list_ui_icon.png"/></button><button aria-label="show compact results" class="layout ...
# </div>
# </div>
# </main>
# </div>
# A <a class="text-muted" href="https://accessibility.mit.edu" rel="noreferrer" target="_blank">Accessibility</a>
# A <a class="text-muted" href="https://creativecommons.org/licenses/by-nc-sa/4.0/" rel="noreferrer" target="_blank">Creative Commons License</a>
# A <a class="text-muted" href="/pages/privacy-and-terms-of-use/">Terms and Conditions</a>
# DIV <div class="container-fluid p-0">
# <div class="row m-0">
# <div class="w-100" id="search-page"><div class="search-page w-100"><div class="container px-lg-0"><div class="search-box py-sm-5 py-md-7 py-lg-5 row"><div class="col-lg-3"></div><div class="col-lg-6 search-box-inner d-flex flex-column align-items-center mb-2 mb-sm-5 mb-md-4 ml-lg-3"><h1>Explore OpenCourseWare</h1><div><span class="align-item-center search-box-description">Search for courses, materials &amp; teaching resources</span></div><div class="w-100 d-flex flex-column align-items-center search-input-wrapper mt-5"><div class="w-100"><form class="search-box d-flex flex-direction-row" role="search"><input aria-label="Search OpenCourseWare" class="w-100 pl-2" placeholder="Search OpenCourseWare" type="search" value=""/><button class="py-2 px-3" type="submit">Search</button></form></div></div></div><div class="col-lg-3"></div></div><div class="row search-filter-drawer mx-auto px-lg-6"><div class="col-12 col-lg-3 mt-3 mt-lg-0 facet-display-wrapper pt-3 pl-0"><div class="active-search-filters"><div class="filter-section-main-title">Filters<button class="clear-all-filters-button" type="button">Clear All</button></div><div class="active-search-filter"><div>Electrical Engineering and Computer Science</div><button aria-label="clear filter" class="remove-filter-button" type="button"><span aria-hidden="true" class="material-icons">close</span></button></div></div><div class="facets filterable-facet mb-3"><button aria-expanded="true" class="filter-section-button pl-3 py-2 pr-0" type="button">Departments<i aria-hidden="true" class="material-icons arrow_drop_down">arrow_drop_down</i></button><div class="input-wrapper"><input class="facet-filter" placeholder="Search Departments" type="text" value=""/><i aria-hidden="true" class="input-postfix-icon material-icons search-icon mt-1">search</i></div><div class="facet-list"><div class="facet-visible checked"><input checked="" id="department-name-electrical-engineering-and-computer-science" name="department_name" type="checkbox" value="Electrical Engineering and Computer Science"/><div class="facet-label-div"><label class="facet-key" for="department-name-electrical-engineering-and-computer-science"><div>Electrical Engineering and Co…</div></label><div class="facet-count">0</div></div></div></div></div><div class="col-12"><footer class="search-footer"><img alt="MIT Open Learning" src="/static_shared/images/mit_ol.svg" width="140px"/><div class="mt-4"><a class="text-muted" href="https://accessibility.mit.edu" rel="noreferrer" target="_blank">Accessibility</a></div><div class="mt-2"><a class="text-muted" href="https://creativecommons.org/licenses/by-nc-sa/4.0/" rel="noreferrer" target="_blank">Creative Commons License</a></div><div class="mt-2"><a class="text-muted" href="/pages/privacy-and-terms-of-use/">Terms and Conditions</a></div><div class="text-muted mt-4">© 2001–2024 Massachusetts Institute of Technology</div></footer></div></div><div class="search-results-area col-12 col-lg-9 pb-2 pt-2 pr-lg-0"><div class="search-toggle facet"><ul class="nav pl-2 pb-2 d-flex flex-direction-row mb-1"><li class="nav-item flex-grow-0"><button class="nav-link search-nav active" type="button">Courses</button></li><li class="nav-item flex-grow-0"><button class="nav-link search-nav" type="button">Resources</button></li><li aria-atomic="true" aria-live="polite" class="nav-item flex-grow-1 d-flex align-items-center justify-content-end results-total"></li><li class="sort-nav-item nav-item d-flex align-items-center justify-content-end">Sort by <select class="ml-2 sort-dropdown"><option value="">Relevance</option><option value="department_course_numbers.sort_coursenum">MIT course #</option><option value="-runs.best_start_date">Date</option></select></li><div class="layout-buttons layout-buttons-desktop"><button aria-label="show detailed results" class="layout-button-left" type="button"><img alt="" aria-hidden="true" src="/images/icons/list_ui_icon.png"/></button><button aria-label="show compact results" class="layout ...
# </div>
# </div>
# A <a class="text-muted" href="https://accessibility.mit.edu" rel="noreferrer" target="_blank">Accessibility</a>
# A <a class="text-muted" href="https://creativecommons.org/licenses/by-nc-sa/4.0/" rel="noreferrer" target="_blank">Creative Commons License</a>
# A <a class="text-muted" href="/pages/privacy-and-terms-of-use/">Terms and Conditions</a>
# DIV <div class="row m-0">
# <div class="w-100" id="search-page"><div class="search-page w-100"><div class="container px-lg-0"><div class="search-box py-sm-5 py-md-7 py-lg-5 row"><div class="col-lg-3"></div><div class="col-lg-6 search-box-inner d-flex flex-column align-items-center mb-2 mb-sm-5 mb-md-4 ml-lg-3"><h1>Explore OpenCourseWare</h1><div><span class="align-item-center search-box-description">Search for courses, materials &amp; teaching resources</span></div><div class="w-100 d-flex flex-column align-items-center search-input-wrapper mt-5"><div class="w-100"><form class="search-box d-flex flex-direction-row" role="search"><input aria-label="Search OpenCourseWare" class="w-100 pl-2" placeholder="Search OpenCourseWare" type="search" value=""/><button class="py-2 px-3" type="submit">Search</button></form></div></div></div><div class="col-lg-3"></div></div><div class="row search-filter-drawer mx-auto px-lg-6"><div class="col-12 col-lg-3 mt-3 mt-lg-0 facet-display-wrapper pt-3 pl-0"><div class="active-search-filters"><div class="filter-section-main-title">Filters<button class="clear-all-filters-button" type="button">Clear All</button></div><div class="active-search-filter"><div>Electrical Engineering and Computer Science</div><button aria-label="clear filter" class="remove-filter-button" type="button"><span aria-hidden="true" class="material-icons">close</span></button></div></div><div class="facets filterable-facet mb-3"><button aria-expanded="true" class="filter-section-button pl-3 py-2 pr-0" type="button">Departments<i aria-hidden="true" class="material-icons arrow_drop_down">arrow_drop_down</i></button><div class="input-wrapper"><input class="facet-filter" placeholder="Search Departments" type="text" value=""/><i aria-hidden="true" class="input-postfix-icon material-icons search-icon mt-1">search</i></div><div class="facet-list"><div class="facet-visible checked"><input checked="" id="department-name-electrical-engineering-and-computer-science" name="department_name" type="checkbox" value="Electrical Engineering and Computer Science"/><div class="facet-label-div"><label class="facet-key" for="department-name-electrical-engineering-and-computer-science"><div>Electrical Engineering and Co…</div></label><div class="facet-count">0</div></div></div></div></div><div class="col-12"><footer class="search-footer"><img alt="MIT Open Learning" src="/static_shared/images/mit_ol.svg" width="140px"/><div class="mt-4"><a class="text-muted" href="https://accessibility.mit.edu" rel="noreferrer" target="_blank">Accessibility</a></div><div class="mt-2"><a class="text-muted" href="https://creativecommons.org/licenses/by-nc-sa/4.0/" rel="noreferrer" target="_blank">Creative Commons License</a></div><div class="mt-2"><a class="text-muted" href="/pages/privacy-and-terms-of-use/">Terms and Conditions</a></div><div class="text-muted mt-4">© 2001–2024 Massachusetts Institute of Technology</div></footer></div></div><div class="search-results-area col-12 col-lg-9 pb-2 pt-2 pr-lg-0"><div class="search-toggle facet"><ul class="nav pl-2 pb-2 d-flex flex-direction-row mb-1"><li class="nav-item flex-grow-0"><button class="nav-link search-nav active" type="button">Courses</button></li><li class="nav-item flex-grow-0"><button class="nav-link search-nav" type="button">Resources</button></li><li aria-atomic="true" aria-live="polite" class="nav-item flex-grow-1 d-flex align-items-center justify-content-end results-total"></li><li class="sort-nav-item nav-item d-flex align-items-center justify-content-end">Sort by <select class="ml-2 sort-dropdown"><option value="">Relevance</option><option value="department_course_numbers.sort_coursenum">MIT course #</option><option value="-runs.best_start_date">Date</option></select></li><div class="layout-buttons layout-buttons-desktop"><button aria-label="show detailed results" class="layout-button-left" type="button"><img alt="" aria-hidden="true" src="/images/icons/list_ui_icon.png"/></button><button aria-label="show compact results" class="layout ...
# </div>
# A <a class="text-muted" href="https://accessibility.mit.edu" rel="noreferrer" target="_blank">Accessibility</a>
# A <a class="text-muted" href="https://creativecommons.org/licenses/by-nc-sa/4.0/" rel="noreferrer" target="_blank">Creative Commons License</a>
# A <a class="text-muted" href="/pages/privacy-and-terms-of-use/">Terms and Conditions</a>
# DIV <div class="w-100" id="search-page"><div class="search-page w-100"><div class="container px-lg-0"><div class="search-box py-sm-5 py-md-7 py-lg-5 row"><div class="col-lg-3"></div><div class="col-lg-6 search-box-inner d-flex flex-column align-items-center mb-2 mb-sm-5 mb-md-4 ml-lg-3"><h1>Explore OpenCourseWare</h1><div><span class="align-item-center search-box-description">Search for courses, materials &amp; teaching resources</span></div><div class="w-100 d-flex flex-column align-items-center search-input-wrapper mt-5"><div class="w-100"><form class="search-box d-flex flex-direction-row" role="search"><input aria-label="Search OpenCourseWare" class="w-100 pl-2" placeholder="Search OpenCourseWare" type="search" value=""/><button class="py-2 px-3" type="submit">Search</button></form></div></div></div><div class="col-lg-3"></div></div><div class="row search-filter-drawer mx-auto px-lg-6"><div class="col-12 col-lg-3 mt-3 mt-lg-0 facet-display-wrapper pt-3 pl-0"><div class="active-search-filters"><div class="filter-section-main-title">Filters<button class="clear-all-filters-button" type="button">Clear All</button></div><div class="active-search-filter"><div>Electrical Engineering and Computer Science</div><button aria-label="clear filter" class="remove-filter-button" type="button"><span aria-hidden="true" class="material-icons">close</span></button></div></div><div class="facets filterable-facet mb-3"><button aria-expanded="true" class="filter-section-button pl-3 py-2 pr-0" type="button">Departments<i aria-hidden="true" class="material-icons arrow_drop_down">arrow_drop_down</i></button><div class="input-wrapper"><input class="facet-filter" placeholder="Search Departments" type="text" value=""/><i aria-hidden="true" class="input-postfix-icon material-icons search-icon mt-1">search</i></div><div class="facet-list"><div class="facet-visible checked"><input checked="" id="department-name-electrical-engineering-and-computer-science" name="department_name" type="checkbox" value="Electrical Engineering and Computer Science"/><div class="facet-label-div"><label class="facet-key" for="department-name-electrical-engineering-and-computer-science"><div>Electrical Engineering and Co…</div></label><div class="facet-count">0</div></div></div></div></div><div class="col-12"><footer class="search-footer"><img alt="MIT Open Learning" src="/static_shared/images/mit_ol.svg" width="140px"/><div class="mt-4"><a class="text-muted" href="https://accessibility.mit.edu" rel="noreferrer" target="_blank">Accessibility</a></div><div class="mt-2"><a class="text-muted" href="https://creativecommons.org/licenses/by-nc-sa/4.0/" rel="noreferrer" target="_blank">Creative Commons License</a></div><div class="mt-2"><a class="text-muted" href="/pages/privacy-and-terms-of-use/">Terms and Conditions</a></div><div class="text-muted mt-4">© 2001–2024 Massachusetts Institute of Technology</div></footer></div></div><div class="search-results-area col-12 col-lg-9 pb-2 pt-2 pr-lg-0"><div class="search-toggle facet"><ul class="nav pl-2 pb-2 d-flex flex-direction-row mb-1"><li class="nav-item flex-grow-0"><button class="nav-link search-nav active" type="button">Courses</button></li><li class="nav-item flex-grow-0"><button class="nav-link search-nav" type="button">Resources</button></li><li aria-atomic="true" aria-live="polite" class="nav-item flex-grow-1 d-flex align-items-center justify-content-end results-total"></li><li class="sort-nav-item nav-item d-flex align-items-center justify-content-end">Sort by <select class="ml-2 sort-dropdown"><option value="">Relevance</option><option value="department_course_numbers.sort_coursenum">MIT course #</option><option value="-runs.best_start_date">Date</option></select></li><div class="layout-buttons layout-buttons-desktop"><button aria-label="show detailed results" class="layout-button-left" type="button"><img alt="" aria-hidden="true" src="/images/icons/list_ui_icon.png"/></button><button aria-label="show compact results" class="la ...
# A <a class="text-muted" href="https://accessibility.mit.edu" rel="noreferrer" target="_blank">Accessibility</a>
# A <a class="text-muted" href="https://creativecommons.org/licenses/by-nc-sa/4.0/" rel="noreferrer" target="_blank">Creative Commons License</a>
# A <a class="text-muted" href="/pages/privacy-and-terms-of-use/">Terms and Conditions</a>
# DIV <div class="search-page w-100"><div class="container px-lg-0"><div class="search-box py-sm-5 py-md-7 py-lg-5 row"><div class="col-lg-3"></div><div class="col-lg-6 search-box-inner d-flex flex-column align-items-center mb-2 mb-sm-5 mb-md-4 ml-lg-3"><h1>Explore OpenCourseWare</h1><div><span class="align-item-center search-box-description">Search for courses, materials &amp; teaching resources</span></div><div class="w-100 d-flex flex-column align-items-center search-input-wrapper mt-5"><div class="w-100"><form class="search-box d-flex flex-direction-row" role="search"><input aria-label="Search OpenCourseWare" class="w-100 pl-2" placeholder="Search OpenCourseWare" type="search" value=""/><button class="py-2 px-3" type="submit">Search</button></form></div></div></div><div class="col-lg-3"></div></div><div class="row search-filter-drawer mx-auto px-lg-6"><div class="col-12 col-lg-3 mt-3 mt-lg-0 facet-display-wrapper pt-3 pl-0"><div class="active-search-filters"><div class="filter-section-main-title">Filters<button class="clear-all-filters-button" type="button">Clear All</button></div><div class="active-search-filter"><div>Electrical Engineering and Computer Science</div><button aria-label="clear filter" class="remove-filter-button" type="button"><span aria-hidden="true" class="material-icons">close</span></button></div></div><div class="facets filterable-facet mb-3"><button aria-expanded="true" class="filter-section-button pl-3 py-2 pr-0" type="button">Departments<i aria-hidden="true" class="material-icons arrow_drop_down">arrow_drop_down</i></button><div class="input-wrapper"><input class="facet-filter" placeholder="Search Departments" type="text" value=""/><i aria-hidden="true" class="input-postfix-icon material-icons search-icon mt-1">search</i></div><div class="facet-list"><div class="facet-visible checked"><input checked="" id="department-name-electrical-engineering-and-computer-science" name="department_name" type="checkbox" value="Electrical Engineering and Computer Science"/><div class="facet-label-div"><label class="facet-key" for="department-name-electrical-engineering-and-computer-science"><div>Electrical Engineering and Co…</div></label><div class="facet-count">0</div></div></div></div></div><div class="col-12"><footer class="search-footer"><img alt="MIT Open Learning" src="/static_shared/images/mit_ol.svg" width="140px"/><div class="mt-4"><a class="text-muted" href="https://accessibility.mit.edu" rel="noreferrer" target="_blank">Accessibility</a></div><div class="mt-2"><a class="text-muted" href="https://creativecommons.org/licenses/by-nc-sa/4.0/" rel="noreferrer" target="_blank">Creative Commons License</a></div><div class="mt-2"><a class="text-muted" href="/pages/privacy-and-terms-of-use/">Terms and Conditions</a></div><div class="text-muted mt-4">© 2001–2024 Massachusetts Institute of Technology</div></footer></div></div><div class="search-results-area col-12 col-lg-9 pb-2 pt-2 pr-lg-0"><div class="search-toggle facet"><ul class="nav pl-2 pb-2 d-flex flex-direction-row mb-1"><li class="nav-item flex-grow-0"><button class="nav-link search-nav active" type="button">Courses</button></li><li class="nav-item flex-grow-0"><button class="nav-link search-nav" type="button">Resources</button></li><li aria-atomic="true" aria-live="polite" class="nav-item flex-grow-1 d-flex align-items-center justify-content-end results-total"></li><li class="sort-nav-item nav-item d-flex align-items-center justify-content-end">Sort by <select class="ml-2 sort-dropdown"><option value="">Relevance</option><option value="department_course_numbers.sort_coursenum">MIT course #</option><option value="-runs.best_start_date">Date</option></select></li><div class="layout-buttons layout-buttons-desktop"><button aria-label="show detailed results" class="layout-button-left" type="button"><img alt="" aria-hidden="true" src="/images/icons/list_ui_icon.png"/></button><button aria-label="show compact results" class="layout-button-right" type="button"><im ...
# A <a class="text-muted" href="https://accessibility.mit.edu" rel="noreferrer" target="_blank">Accessibility</a>
# A <a class="text-muted" href="https://creativecommons.org/licenses/by-nc-sa/4.0/" rel="noreferrer" target="_blank">Creative Commons License</a>
# A <a class="text-muted" href="/pages/privacy-and-terms-of-use/">Terms and Conditions</a>
# ...
# DIV <div class="card-contents"><svg aria-labelledby="0yjzds-aria" height="137" preserveaspectratio="none" role="img" style="width: 100%; height: 137px;" width="1000"><title id="0yjzds-aria">Loading...</title><rect clip-path="url(#0yjzds-diff)" height="100%" role="presentation" style='fill: url("#0yjzds-animated-diff");' width="100%" x="0" y="0"></rect><defs role="presentation"><clippath id="0yjzds-diff"><rect height="20" rx="5" ry="5" width="60%" x="0" y="0"></rect><rect height="16" rx="5" ry="5" width="60%" x="0" y="40"></rect><rect height="16" rx="5" ry="5" width="60%" x="0" y="58"></rect><rect height="24" rx="5" ry="5" width="170" x="0" y="113"></rect><rect height="128" rx="5" ry="5" width="34%" x="66%" y="0"></rect></clippath><lineargradient id="0yjzds-animated-diff"><stop offset="0%" stop-color="#f5f6f7" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="-2; -2; 1"></animate></stop><stop offset="50%" stop-color="#eee" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="-1; -1; 2"></animate></stop><stop offset="100%" stop-color="#f5f6f7" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="0; 0; 3"></animate></stop></lineargradient></defs></svg></div>
# DIV <div class="post-content-loader"><div class="card compact-post-summary"><div class="card-contents"><svg aria-labelledby="pms1zv-aria" height="137" preserveaspectratio="none" role="img" style="width: 100%; height: 137px;" width="1000"><title id="pms1zv-aria">Loading...</title><rect clip-path="url(#pms1zv-diff)" height="100%" role="presentation" style='fill: url("#pms1zv-animated-diff");' width="100%" x="0" y="0"></rect><defs role="presentation"><clippath id="pms1zv-diff"><rect height="20" rx="5" ry="5" width="60%" x="0" y="0"></rect><rect height="16" rx="5" ry="5" width="60%" x="0" y="40"></rect><rect height="16" rx="5" ry="5" width="60%" x="0" y="58"></rect><rect height="24" rx="5" ry="5" width="170" x="0" y="113"></rect><rect height="128" rx="5" ry="5" width="34%" x="66%" y="0"></rect></clippath><lineargradient id="pms1zv-animated-diff"><stop offset="0%" stop-color="#f5f6f7" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="-2; -2; 1"></animate></stop><stop offset="50%" stop-color="#eee" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="-1; -1; 2"></animate></stop><stop offset="100%" stop-color="#f5f6f7" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="0; 0; 3"></animate></stop></lineargradient></defs></svg></div></div></div>
# DIV <div class="card compact-post-summary"><div class="card-contents"><svg aria-labelledby="pms1zv-aria" height="137" preserveaspectratio="none" role="img" style="width: 100%; height: 137px;" width="1000"><title id="pms1zv-aria">Loading...</title><rect clip-path="url(#pms1zv-diff)" height="100%" role="presentation" style='fill: url("#pms1zv-animated-diff");' width="100%" x="0" y="0"></rect><defs role="presentation"><clippath id="pms1zv-diff"><rect height="20" rx="5" ry="5" width="60%" x="0" y="0"></rect><rect height="16" rx="5" ry="5" width="60%" x="0" y="40"></rect><rect height="16" rx="5" ry="5" width="60%" x="0" y="58"></rect><rect height="24" rx="5" ry="5" width="170" x="0" y="113"></rect><rect height="128" rx="5" ry="5" width="34%" x="66%" y="0"></rect></clippath><lineargradient id="pms1zv-animated-diff"><stop offset="0%" stop-color="#f5f6f7" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="-2; -2; 1"></animate></stop><stop offset="50%" stop-color="#eee" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="-1; -1; 2"></animate></stop><stop offset="100%" stop-color="#f5f6f7" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="0; 0; 3"></animate></stop></lineargradient></defs></svg></div></div>
# DIV <div class="card-contents"><svg aria-labelledby="pms1zv-aria" height="137" preserveaspectratio="none" role="img" style="width: 100%; height: 137px;" width="1000"><title id="pms1zv-aria">Loading...</title><rect clip-path="url(#pms1zv-diff)" height="100%" role="presentation" style='fill: url("#pms1zv-animated-diff");' width="100%" x="0" y="0"></rect><defs role="presentation"><clippath id="pms1zv-diff"><rect height="20" rx="5" ry="5" width="60%" x="0" y="0"></rect><rect height="16" rx="5" ry="5" width="60%" x="0" y="40"></rect><rect height="16" rx="5" ry="5" width="60%" x="0" y="58"></rect><rect height="24" rx="5" ry="5" width="170" x="0" y="113"></rect><rect height="128" rx="5" ry="5" width="34%" x="66%" y="0"></rect></clippath><lineargradient id="pms1zv-animated-diff"><stop offset="0%" stop-color="#f5f6f7" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="-2; -2; 1"></animate></stop><stop offset="50%" stop-color="#eee" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="-1; -1; 2"></animate></stop><stop offset="100%" stop-color="#f5f6f7" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="0; 0; 3"></animate></stop></lineargradient></defs></svg></div>
# DIV <div class="post-content-loader"><div class="card compact-post-summary"><div class="card-contents"><svg aria-labelledby="420vmjh-aria" height="137" preserveaspectratio="none" role="img" style="width: 100%; height: 137px;" width="1000"><title id="420vmjh-aria">Loading...</title><rect clip-path="url(#420vmjh-diff)" height="100%" role="presentation" style='fill: url("#420vmjh-animated-diff");' width="100%" x="0" y="0"></rect><defs role="presentation"><clippath id="420vmjh-diff"><rect height="20" rx="5" ry="5" width="60%" x="0" y="0"></rect><rect height="16" rx="5" ry="5" width="60%" x="0" y="40"></rect><rect height="16" rx="5" ry="5" width="60%" x="0" y="58"></rect><rect height="24" rx="5" ry="5" width="170" x="0" y="113"></rect><rect height="128" rx="5" ry="5" width="34%" x="66%" y="0"></rect></clippath><lineargradient id="420vmjh-animated-diff"><stop offset="0%" stop-color="#f5f6f7" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="-2; -2; 1"></animate></stop><stop offset="50%" stop-color="#eee" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="-1; -1; 2"></animate></stop><stop offset="100%" stop-color="#f5f6f7" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="0; 0; 3"></animate></stop></lineargradient></defs></svg></div></div></div>
# DIV <div class="card compact-post-summary"><div class="card-contents"><svg aria-labelledby="420vmjh-aria" height="137" preserveaspectratio="none" role="img" style="width: 100%; height: 137px;" width="1000"><title id="420vmjh-aria">Loading...</title><rect clip-path="url(#420vmjh-diff)" height="100%" role="presentation" style='fill: url("#420vmjh-animated-diff");' width="100%" x="0" y="0"></rect><defs role="presentation"><clippath id="420vmjh-diff"><rect height="20" rx="5" ry="5" width="60%" x="0" y="0"></rect><rect height="16" rx="5" ry="5" width="60%" x="0" y="40"></rect><rect height="16" rx="5" ry="5" width="60%" x="0" y="58"></rect><rect height="24" rx="5" ry="5" width="170" x="0" y="113"></rect><rect height="128" rx="5" ry="5" width="34%" x="66%" y="0"></rect></clippath><lineargradient id="420vmjh-animated-diff"><stop offset="0%" stop-color="#f5f6f7" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="-2; -2; 1"></animate></stop><stop offset="50%" stop-color="#eee" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="-1; -1; 2"></animate></stop><stop offset="100%" stop-color="#f5f6f7" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="0; 0; 3"></animate></stop></lineargradient></defs></svg></div></div>
# DIV <div class="card-contents"><svg aria-labelledby="420vmjh-aria" height="137" preserveaspectratio="none" role="img" style="width: 100%; height: 137px;" width="1000"><title id="420vmjh-aria">Loading...</title><rect clip-path="url(#420vmjh-diff)" height="100%" role="presentation" style='fill: url("#420vmjh-animated-diff");' width="100%" x="0" y="0"></rect><defs role="presentation"><clippath id="420vmjh-diff"><rect height="20" rx="5" ry="5" width="60%" x="0" y="0"></rect><rect height="16" rx="5" ry="5" width="60%" x="0" y="40"></rect><rect height="16" rx="5" ry="5" width="60%" x="0" y="58"></rect><rect height="24" rx="5" ry="5" width="170" x="0" y="113"></rect><rect height="128" rx="5" ry="5" width="34%" x="66%" y="0"></rect></clippath><lineargradient id="420vmjh-animated-diff"><stop offset="0%" stop-color="#f5f6f7" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="-2; -2; 1"></animate></stop><stop offset="50%" stop-color="#eee" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="-1; -1; 2"></animate></stop><stop offset="100%" stop-color="#f5f6f7" stop-opacity="1"><animate attributename="offset" dur="2s" keytimes="0; 0.25; 1" repeatcount="indefinite" values="0; 0; 3"></animate></stop></lineargradient></defs></svg></div>
# DIV <div class="ed48cdd3e1a" data-appzi-dom="1" id="bklvmjbt5c-fre46k8wfys"></div>
# DIV <div class="" data-appzi-dom="1" id="appzi-slo-lvmjbt5d-8ki7f1ij04p"><div id="appzi-sli-lvmjbt5d-8ki7f1ij04p"><iframe data-appzi-dom="1" frameborder="0" height="100%" srcdoc='&lt;html&gt;&lt;head&gt;&lt;meta name="viewport" content="width=device-width, initial-scale=1" /&gt;&lt;meta charset="utf-8" /&gt;&lt;/head&gt;&lt;body&gt;&lt;div id="lvmjbt5j-bdc8yscjcaw"&gt;&lt;/div&gt;&lt;div style="display:none" id="eeque2x"&gt;{"iid":"lvmjbt5d-8ki7f1ij04p","root":"lvmjbt5j-bdc8yscjcaw","origin":"https://ocw.mit.edu/search/","flags":{}}&lt;/div&gt;&lt;script async src="https://w.appzi.io/l-v2320-kt9d7h.js"&gt;&lt;/script&gt;&lt;/body&gt;&lt;/html&gt;' title="Feedback Button" width="100%"></iframe></div></div>
# DIV <div id="appzi-sli-lvmjbt5d-8ki7f1ij04p"><iframe data-appzi-dom="1" frameborder="0" height="100%" srcdoc='&lt;html&gt;&lt;head&gt;&lt;meta name="viewport" content="width=device-width, initial-scale=1" /&gt;&lt;meta charset="utf-8" /&gt;&lt;/head&gt;&lt;body&gt;&lt;div id="lvmjbt5j-bdc8yscjcaw"&gt;&lt;/div&gt;&lt;div style="display:none" id="eeque2x"&gt;{"iid":"lvmjbt5d-8ki7f1ij04p","root":"lvmjbt5j-bdc8yscjcaw","origin":"https://ocw.mit.edu/search/","flags":{}}&lt;/div&gt;&lt;script async src="https://w.appzi.io/l-v2320-kt9d7h.js"&gt;&lt;/script&gt;&lt;/body&gt;&lt;/html&gt;' title="Feedback Button" width="100%"></iframe></div>
# ['https://ocw.mit.edu/', 'https://giving.mit.edu/give/to/ocw/?utm_source=ocw&utm_medium=homepage_banner&utm_campaign=nextgen_home', 'https://ocw.mit.edu/about', 'https://mitocw.zendesk.com/hc/en-us', 'https://ocw.mit.edu/contact', 'https://ocw.mit.edu/', 'https://giving.mit.edu/give/to/ocw/?utm_source=ocw&utm_medium=homepage_banner&utm_campaign=nextgen_home', 'https://ocw.mit.edu/about', 'https://mitocw.zendesk.com/hc/en-us', 'https://ocw.mit.edu/contact', 'https://accessibility.mit.edu', 'https://creativecommons.org/licenses/by-nc-sa/4.0/', 'https://ocw.mit.edu/pages/privacy-and-terms-of-use/', 'https://ocw.mit.edu/', 'https://giving.mit.edu/give/to/ocw/?utm_source=ocw&utm_medium=homepage_banner&utm_campaign=nextgen_home', 'https://ocw.mit.edu/about', 'https://mitocw.zendesk.com/hc/en-us', 'https://ocw.mit.edu/contact', 'https://ocw.mit.edu/', 'https://giving.mit.edu/give/to/ocw/?utm_source=ocw&utm_medium=homepage_banner&utm_campaign=nextgen_home', 'https://ocw.mit.edu/about', 'https://mitocw.zendesk.com/hc/en-us', 'https://ocw.mit.edu/contact', 'https://accessibility.mit.edu', 'https://creativecommons.org/licenses/by-nc-sa/4.0/', 'https://ocw.mit.edu/pages/privacy-and-terms-of-use/', 'https://ocw.mit.edu/', 'https://giving.mit.edu/give/to/ocw/?utm_source=ocw&utm_medium=homepage_banner&utm_campaign=nextgen_home', 'https://ocw.mit.edu/about', 'https://mitocw.zendesk.com/hc/en-us', 'https://ocw.mit.edu/contact', 'https://ocw.mit.edu/', 'https://giving.mit.edu/give/to/ocw/?utm_source=ocw&utm_medium=homepage_banner&utm_campaign=nextgen_home', 'https://ocw.mit.edu/about', 'https://mitocw.zendesk.com/hc/en-us', 'https://ocw.mit.edu/contact', 'https://ocw.mit.edu/', 'https://giving.mit.edu/give/to/ocw/?utm_source=ocw&utm_medium=homepage_banner&utm_campaign=nextgen_home', 'https://ocw.mit.edu/about', 'https://mitocw.zendesk.com/hc/en-us', 'https://ocw.mit.edu/contact', 'https://ocw.mit.edu/', 'https://giving.mit.edu/give/to/ocw/?utm_source=ocw&utm_medium=homepage_banner&utm_campaign=nextgen_home', 'https://ocw.mit.edu/about', 'https://mitocw.zendesk.com/hc/en-us', 'https://ocw.mit.edu/contact', 'https://ocw.mit.edu/', 'https://ocw.mit.edu/', 'https://giving.mit.edu/give/to/ocw/?utm_source=ocw&utm_medium=homepage_banner&utm_campaign=nextgen_home', 'https://ocw.mit.edu/about', 'https://mitocw.zendesk.com/hc/en-us', 'https://ocw.mit.edu/contact', 'https://accessibility.mit.edu', 'https://creativecommons.org/licenses/by-nc-sa/4.0/', 'https://ocw.mit.edu/pages/privacy-and-terms-of-use/', 'https://accessibility.mit.edu', 'https://creativecommons.org/licenses/by-nc-sa/4.0/', 'https://ocw.mit.edu/pages/privacy-and-terms-of-use/', 'https://accessibility.mit.edu', 'https://creativecommons.org/licenses/by-nc-sa/4.0/', 'https://ocw.mit.edu/pages/privacy-and-terms-of-use/', 'https://accessibility.mit.edu', 'https://creativecommons.org/licenses/by-nc-sa/4.0/', 'https://ocw.mit.edu/pages/privacy-and-terms-of-use/', 'https://accessibility.mit.edu', 'https://creativecommons.org/licenses/by-nc-sa/4.0/', 'https://ocw.mit.edu/pages/privacy-and-terms-of-use/', 'https://accessibility.mit.edu', 'https://creativecommons.org/licenses/by-nc-sa/4.0/', 'https://ocw.mit.edu/pages/privacy-and-terms-of-use/', 'https://accessibility.mit.edu', 'https://creativecommons.org/licenses/by-nc-sa/4.0/', 'https://ocw.mit.edu/pages/privacy-and-terms-of-use/', 'https://accessibility.mit.edu', 'https://creativecommons.org/licenses/by-nc-sa/4.0/', 'https://ocw.mit.edu/pages/privacy-and-terms-of-use/', 'https://accessibility.mit.edu', 'https://creativecommons.org/licenses/by-nc-sa/4.0/', 'https://ocw.mit.edu/pages/privacy-and-terms-of-use/', 'https://accessibility.mit.edu', 'https://creativecommons.org/licenses/by-nc-sa/4.0/', 'https://ocw.mit.edu/pages/privacy-and-terms-of-use/']

# %%
def get_links(url):
    driver = webdriver.Chrome() # using Selenium 
    driver.get(url) #link to scrape 
    res = driver.page_source

    #res = request.urlopen(url)
    driver.quit() #selenium

    return list(parse_links(url, res))

# %%
def writelines(filename, data):
    with open(filename, 'w') as fout:
        for d in data:
            print(d, file=fout)

# %%
def crawl(root, wanted_content=[], within_domain=True):
    '''Crawl the url specified by `root`.
    `wanted_content` is a list of content types to crawl
    `within_domain` specifies whether the crawler should limit itself to the domain of `root`
    '''
    # TODO: implement

    queue = Queue()
    queue.put(root)

    visited = []
    extracted = []

    while not queue.empty(): #and len(visited) < 200
        url = queue.get()
        try:
            req = request.urlopen(url)
            html = req.read()

            if url not in visited:
                visited.append(url)
                visitlog.debug(url)

                #test uncomment    
                for ex in extract_information(url, html):
                    extracted.append(ex)
                    extractlog.debug(ex)

                for link, title in parse_links(url, html):
                    if not is_self_referencing_link(url, link): 
                        if within_domain and is_within_domain(url, link):
                            if len(wanted_content) == 0: 
                                queue.put(link)
                            elif len(wanted_content) > 0 and req.headers['Content-Type'] in wanted_content:
                                queue.put(link)                

                    soup = BeautifulSoup(html, 'html.parser')
                    div = soup.find('div', class_='mt-2 lead-sm html-data')
                    if div:
                        text = div.text.strip()
                        extracted.append((url, 'HTML_DATA', text))
                    for link, title in parse_links(url, html):
                        if not is_self_referencing_link(url, link): 
                            if within_domain and is_within_domain(url, link):
                                if len(wanted_content) == 0: 
                                    queue.put(link)
                                elif len(wanted_content) > 0 and req.headers['Content-Type'] in wanted_content:
                                    queue.put(link)                


        except Exception as e:
            print(e, url)

    return visited, extracted
